# %% [markdown]
# # PyfA Assignment 3
#
# **Learning topics:**
# - Pandas multiindex
# - Pandas data wrangling
# - Creating and interpretting plots
#
# **Datasets:**
# - cdc_birth_data.csv
# - marathon_dataset.csv
#
# **Please do not share this material on any platform or by any other means.**
#
# ### **Important Notes:**
#
# * Purpose of the assignment is to assess your knowledge and command of the Python programming language and your ability to resolve common errors. Grading is based on the code you are submitting, not the formatting of the results.
# * Please use the examples as a guideline, you are not expected to have the same formatting as the example, unless it is a formatting question.
# * Remember, there are many ways to code that can lead to the correct answer, do not hesitate to exercise your own style and python programming coventions.

# %% [markdown]
# ---
# # Pandas `MultiIndex`
# ## Q1A: Use the following data to create a Pandas Series object with `State` and `Year` as the index.
#
#
# ```python
# index = [('California',2000),('California',2010),
#         ('New York', 2000),('New York',2010),
#         ('Texas',2000),('Texas',2010)]
# populations =[33871648,37253956,
#              18976457,19378102,
#              20851820,25145561]
# ```

# %%
from pandas import Series

# %%
import pandas as pd

# %%
index = [('California',2000),('California',2010),
        ('New York', 2000),('New York',2010),
        ('Texas',2000),('Texas',2010)]
populations =[33871648,37253956,
             18976457,19378102,
             20851820,25145561]

# %%
# add your code and explanation here
data = pd.Series(data=populations, index=index)

# %%
data
# Out:
# (California, 2000)    33871648
# (California, 2010)    37253956
# (New York, 2000)      18976457
# (New York, 2010)      19378102
# (Texas, 2000)         20851820
# (Texas, 2010)         25145561
# dtype: int64

# %% [markdown]
# ## Q1B:Choose all values from 2010.

# %%
# add your code and explanation here
data[[i for i in data.index if i[1]==2010]]
# Out:
# (California, 2010)    37253956
# (New York, 2010)      19378102
# (Texas, 2010)         25145561
# dtype: int64

# %% [markdown]
# ## Q1C: Convert the series object created in 1A to a dataframe where index becomes `state` (name of the index is `state` as well).

# %%
# add your code and explanation here
a,b = map(list,zip(*index))

# %%
a
# Out:
# ['California', 'California', 'New York', 'New York', 'Texas', 'Texas']

# %%
b
# Out:
# [2000, 2010, 2000, 2010, 2000, 2010]

# %%
list3 = [list(a) for a in zip(a, b, populations)]

# %%
list3
# Out:
# [['California', 2000, 33871648],
#  ['California', 2010, 37253956],
#  ['New York', 2000, 18976457],
#  ['New York', 2010, 19378102],
#  ['Texas', 2000, 20851820],
#  ['Texas', 2010, 25145561]]

# %%
df = pd.DataFrame(data = list3)

# %%
df
# Out:
#             0     1         2
# 0  California  2000  33871648
# 1  California  2010  37253956
# 2    New York  2000  18976457
# 3    New York  2010  19378102
# 4       Texas  2000  20851820
# 5       Texas  2010  25145561

# %%
df_new = df.rename(columns={0: 'state',1: 'year', 2: 'populations'})

# %%
df_new.set_index('state')
# Out:
#             year  populations
# state
# California  2000     33871648
# California  2010     37253956
# New York    2000     18976457
# New York    2010     19378102
# Texas       2000     20851820
# Texas       2010     25145561

# %% [markdown]
# ----
# # Pandas Data Wrangling
# USA Centers for Disease Control and Prevention - US Birth Dataset
# (source: http://www.cdc.gov/nchs/data_access/Vitalstatsonline.htm)
#
# Data dictionary:
# year, month, day, gender (F=Female or M= Male), births (number of births on the date)
#
# ## Question 2A: Read in the "cdc_birth_data.csv". Add a `decade` column (if year is 1969, the decade is 1960). Use a pivot table to show the total number of female and male births by decade. Interpret how male births compare to female births.

# %%
# add your code and explanation here
birth = pd.read_csv('cdc_birth_data.csv')

# %%
birth.head()
# Out:
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548

# %%
birth['decade'] = birth['year'] - 9

# %%
birth.head()
# Out:
#    year  month  day gender  births  decade
# 0  1969      1  1.0      F    4046    1960
# 1  1969      1  1.0      M    4440    1960
# 2  1969      1  2.0      F    4454    1960
# 3  1969      1  2.0      M    4548    1960
# 4  1969      1  3.0      F    4548    1960

# %%
birth.tail()
# Out:
#        year  month  day gender  births  decade
# 15542  2008     10  NaN      M  183219    1999
# 15543  2008     11  NaN      F  158939    1999
# 15544  2008     11  NaN      M  165468    1999
# 15545  2008     12  NaN      F  173215    1999
# 15546  2008     12  NaN      M  181235    1999

# %%
import numpy as np

# %%
table = pd.pivot_table(birth, values='births', index=['gender'],
                    columns=['decade'], aggfunc=np.sum)

# %%
table
# Out:
# decade     1960     1961     1962     1963     1964     1965     1966  \
# gender
# F       1753634  1819164  1736774  1592347  1533102  1543005  1535546
# M       1846572  1918636  1826774  1673888  1613023  1627626  1618010
#
# decade     1967     1968     1969  ...     1990     1991     1992     1993  \
# gender                             ...
# F       1547613  1623363  1626324  ...  1934510  1984255  1970770  1966519
# M       1628863  1708796  1711976  ...  2028955  2079568  2060761  2060857
#
# decade     1994     1995     1996     1997     1998     1999
# gender
# F       1999387  2010710  2022892  2084957  2111890  2077929
# M       2096705  2108197  2122727  2188268  2212118  2177227
#
# [2 rows x 40 columns]

# %% [markdown]
# ## Question 2B: use a `Pandas.DataFrame.plot()` to show the total number of births by gender (using 2A)

# %%
# add your code and explanation here
by_gender = birth.groupby('gender')['births'].agg(sum)
by_gender.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='gender'>

# %% [markdown]
# ## Question 2C: Calculate the 25th, 50th and 75th percentile of births data. (Hint: use np.percentile)

# %%
# add your code and explanation here
quartile_25th = np.percentile(birth['births'], 25)

# %%
quartile_25th
# Out:
# 4358.0

# %%
quartile_50th = np.percentile(birth['births'], 50)

# %%
quartile_50th
# Out:
# 4814.0

# %%
quartile_75th = np.percentile(birth['births'], 75)

# %%
quartile_75th
# Out:
# 5289.5

# %% [markdown]
# ## Question 2D: If sigma is defined as below, remove the records out side of 5sigma. Use the cleaned data in 2E and 2F.
#
# ```sigma = 0.74 * (quartile_75th - quartile_25th)```
#
# `quartile_75th` and `quartile_25th` are calculated in 2c.

# %%
# add your code and explanation here
sigma = 0.74 * (quartile_75th - quartile_25th)

# %%
outlier = sigma*5

# %%
birth = birth.loc[birth['births'] > outlier]

# %% [markdown]
# ## Question 2E: Create a graph that shows which day is the most popular dayof the week for giving birth in each decade.
#
# To accomplish this goal, you can: Create a new column named `dayoftheweek`.(Monday==1) Plot mean of `birth` data by `dayoftheweek` for each `decade`.
#
# **By looking at the graph, what can you tell about the popularity of Sundays vs Tuesdays?.**

# %%
birth.isnull().sum()
# Out:
# year        0
# month       0
# day       480
# gender      0
# births      0
# decade      0
# dtype: int64

# %%
birth = birth.dropna(subset=['day'])

# %%
birth.isnull().sum()
# Out:
# year      0
# month     0
# day       0
# gender    0
# births    0
# decade    0
# dtype: int64

# %%
birth.dtypes
# Out:
# year        int64
# month       int64
# day       float64
# gender     object
# births      int64
# decade      int64
# dtype: object

# %%
# add your code and explanation here
def new_row(row):
    if row['day'] == 1:
        return 'Monday'
    if row['day'] == 2:
        return 'Tuesday'
    if row['day'] == 3:
        return 'Wednesday'
    if row['day'] == 4:
        return 'Thursday'
    if row['day'] == 5:
        return 'Friday'
    if row['day'] == 6:
        return 'Saturday'
    if row['day'] == 7:
        return 'Sunday'

# %%
birth['dayoftheweek'] = birth.apply (lambda row: new_row(row), axis=1)

# %%
birth.head()
# Out:
#    year  month  day gender  births  decade dayoftheweek
# 0  1969      1  1.0      F    4046    1960       Monday
# 1  1969      1  1.0      M    4440    1960       Monday
# 2  1969      1  2.0      F    4454    1960      Tuesday
# 3  1969      1  2.0      M    4548    1960      Tuesday
# 4  1969      1  3.0      F    4548    1960    Wednesday

# %%
by_day = birth.groupby('dayoftheweek')['births'].mean()

# %%
by_day1 = birth.groupby('day')['births'].mean()

# %%
by_day.plot(kind = 'bar')

# %%
by_day1.plot(kind='bar')

# %% [markdown]
# ## Question 2F: Plot the average births by the day of the year.
# You'll be plotting the average of births on each day Jan 1 through Dec 31st inclusive.

# %%
# add your code and explanation here
by_day1 = birth.groupby('day')['births'].mean()
by_day1.plot(kind='bar')

# %% [markdown]
# ---
# # Plotting Data with `Seaborn` Library

# %% [markdown]
# ## Question 3A: Read the marathon_dataset.csv and use `seaborn.joinplot()` to plot the relationship between the first-half marathon finishing time and the full-marathon finishing time.
#
# **Data dictionary**: each observation shows the `age`, `gender` of the runner. `split_sec` is the finishing time of the first-half marathon. `final_sec` is the full-marathon finishing time.

# %%
import seaborn as sns

# %%
# add your code and explanation here
marathon = pd.read_csv('marathon_dataset.csv', delimiter = ';')

# %%
marathon.head()
# Out:
#    age gender  split_sec  final_sec
# 0   33      M     3938.0     7731.0
# 1   32      M     3986.0     7768.0
# 2   31      M     4009.0     7842.0
# 3   38      M     3976.0     8025.0
# 4   31      M     3992.0     8039.0

# %%
marathon.describe()
# Out:
#                 age     split_sec     final_sec    racing_str     age_group
# count  37250.000000  37250.000000  37250.000000  37250.000000  37250.000000
# mean      40.697369   7434.425664  17289.303597      0.130887     36.223624
# std       10.220043   1375.093890   3812.145345      0.061825     10.718349
# min       17.000000   3921.000000   7731.000000     -0.237000     10.000000
# 25%       33.000000   6505.000000  14544.000000      0.088254     30.000000
# 50%       40.000000   7273.000000  17065.000000      0.134711     40.000000
# 75%       48.000000   8171.000000  19656.000000      0.175026     40.000000
# max       86.000000  17989.000000  36068.000000      0.579326     80.000000

# %%
marathon.shape
# Out:
# (37250, 6)

# %%
time = marathon[['split_sec','final_sec']]

# %%
with sns.axes_style('white'):
    g = sns.jointplot("split_sec", "final_sec", marathon, kind='hex')
    g.ax_joint.plot(np.linspace(3921, 17989),
                    np.linspace(7731, 36068),':k')

# %%
sns.jointplot(data=time, x="final_sec", y="split_sec")

# %% [markdown]
# ## Question 3B: Create a distribution plot of runners' racing strategy
# Let's define a new variable, to identify the runners' racing strategy: *negative-split (those who have a slower first half and faster second half),  *positive-split* (those who have a faster first half and slower second half).
#
#     racing_str = 1 - (2 * split_sec) / final_sec
#
# If racing strategy is less than zero, this indicates runner's strategy is negative-split.

# %%
# add your code and explanation here
marathon['racing_str'] = 1 - (2 * marathon['split_sec']) / marathon['final_sec']

# %%
sns.distplot(marathon['racing_str'], hist=True)

# %%
sns.kdeplot(marathon['racing_str'])

# %% [markdown]
# ## Question 3C: Are there any correlation between any of the variables? Explain.
#
# You can use `sns.PairGrid` function or similar.

# %%
# add your code and explanation here
g = sns.PairGrid(marathon)
g.map(sns.scatterplot)

# %% [markdown]
# # The split_sec and final_sec have the correlation because these two variable have the linear relationship and racing_str with final_sec probabily have the correlation because the faster runners may will split the time more even

# %% [markdown]
# ## Question 3D: What is the distribution of race strategy by gender? What is your interpretation of the graph?

# %%
import matplotlib.pyplot as plt

# %%
marathon.head()
# Out:
#    age gender  split_sec  final_sec  racing_str
# 0   33      M     3938.0     7731.0   -0.018756
# 1   32      M     3986.0     7768.0   -0.026262
# 2   31      M     4009.0     7842.0   -0.022443
# 3   38      M     3976.0     8025.0    0.009097
# 4   31      M     3992.0     8039.0    0.006842

# %%
sns.kdeplot(marathon.racing_str[marathon.gender=='M'], label='men', shade=True)
sns.kdeplot(marathon.racing_str[marathon.gender=='W'], label='women', shade=True)
plt.xlabel('racing_str')
plt.show()

# %% [markdown]
# # In terms of human function, men should be more athletic than women so there the man runners looks like split the time more even which means the man runner may faster than the women runners

# %% [markdown]
# ## Question 3E : Compare the distributions of men and women (3D) as a function of age, use a violin plot.
#
# Create a column named `age_group` to group decade of age, e.g. if a person is 36 years old, `age_group` = 30. Then create a violin plot to show by age group by gender, the distribution of race strategy.

# %%
# add your code and explanation here
marathon['age_group'] = marathon.age.map(lambda age: 10 * (age // 10))

# %%
marathon.head()
# Out:
#    age gender  split_sec  final_sec  racing_str  age_group
# 0   33      M     3938.0     7731.0   -0.018756         30
# 1   32      M     3986.0     7768.0   -0.026262         30
# 2   31      M     4009.0     7842.0   -0.022443         30
# 3   38      M     3976.0     8025.0    0.009097         30
# 4   31      M     3992.0     8039.0    0.006842         30

# %%
with sns.axes_style(style='darkgrid'):
    sns.violinplot("age_group", "racing_str", hue="gender", data=marathon,
                   split=True, inner="quartile",
                   palette=["lightblue", "lightpink"]);

# %% [markdown]
# **Assignment 3 complete.**
